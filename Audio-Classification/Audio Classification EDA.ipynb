# %% [markdown]
# # Audio Classification Using Machine Learning

# %%
# !pip install librosa

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = r"C:\Users\User\Desktop\Jupyter Notebook Practice\Audio Classification EDA\Audio Data\UrbanSound8K/sample2.wav"

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
##sample 1 sound
plt.figure(figsize=(14,5))
data, sample_rate = librosa.load(filename)
librosa.display.waveshow(data, sr = sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !dir
# Out:
#  Volume in drive C is WIN-10
#  Volume Serial Number is 5E8C-06FA
#
#  Directory of C:\Users\User\Desktop\Jupyter Notebook Practice\Audio Classification EDA
#
# 08/08/2023  12:43 AM    <DIR>          .
# 08/08/2023  12:43 AM    <DIR>          ..
# 08/08/2023  12:21 AM    <DIR>          .ipynb_checkpoints
# 08/08/2023  12:43 AM             7,584 Audio Classification EDA.ipynb
# 08/08/2023  12:22 AM    <DIR>          Audio Data
#                1 File(s)          7,584 bytes
#                4 Dir(s)  156,875,485,184 bytes free

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio = wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[1263, 2207],
#        [1207, 2478],
#        [1000, 2619],
#        ...,
#        [-792,  423],
#        [-654,  732],
#        [-633,  988]], dtype=int16)

# %% [markdown]
# ## Audio Classification Data Preprocessing

# %%
import librosa
audio_file_path = r"C:\Users\User\Desktop\Jupyter Notebook Practice\Audio Classification EDA\Audio Data\UrbanSound8K\audio\fold5/100263-2-0-3.wav"
librosa_audio_data, librosa_sample_rate = librosa.load(audio_file_path)

# %%
print(librosa_audio_data)
# Out:
# [ 0.00331575  0.00467553  0.00361099 ... -0.00376796 -0.00347471
#  -0.00357828]

# %%
plt.figure(figsize=(12,4))
plt.plot(librosa_audio_data)

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio = wav.read(audio_file_path)

# %%
plt.figure(figsize=(12,4))
plt.plot(wave_audio)

# %%
mfccs = librosa.feature.mfcc(y=librosa_audio_data, sr=librosa_sample_rate, n_mfcc=40)
print(mfccs.shape)
# Out:
# (40, 173)
